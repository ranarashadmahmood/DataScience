# %% [markdown]
# # Variabale are nothing but reserved momor locations to store values

# %% [markdown]
# # Data Type

# %% [markdown]
# ## Integer

# %%
int a = 0; 
string a = 0
float a = 0
double a = 0

# %%
a = 4 
print(a)
print(type(a))
# Out:
# 4
# <class 'int'>

# %% [markdown]
# ## Float

# %%
b = 5.6 
print(b)
print(type(b))
# Out:
# 5.6
# <class 'float'>

# %% [markdown]
# ## String

# %%
# c = 'dsdssddd'
c = "1=one 2=two 3=three"
print(c)
print(type(c))
# Out:
# 1=one 2=two 3=three
# <class 'str'>

# %% [markdown]
# ## convertions

# %%
print(type(a))

a = float(a) # integer to float

print(type(a))
a = str(a)
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ## Bool

# %%
e = True

print(type(e))
f = False 
print(type(f))
# Out:
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# ## Complex

# %%
g = 4+5j
print(type(g))
# Out:
# <class 'complex'>

# %% [markdown]
# # keyword are the reserved words in python. It cannot use as a variable name,function name or any other identifier

# %%
# keyword  as , None , for ,while ,in etc
as = 4
# Out:
#   File "<ipython-input-18-b29d966fb839>", line 2
#     as = 4
#     ^
# SyntaxError: invalid syntax

# %%
import keyword

# %%
keyword.iskeyword('none')
# Out:
# False

# %%
keyword.iskeyword('None')
# Out:
# True

# %%
keyword.iskeyword('for')
# Out:
# True

# %%
keyword.iskeyword('For')
# Out:
# False
